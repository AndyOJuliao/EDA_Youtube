# %% [markdown]
# # EDA Youtube and TOP 1000 Youtubers Challenge - Onyxdata

# %% [markdown]
# ### 1. Importando bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Lendo dataset

# %%
df = pd.read_excel('dataset3.xlsx')
df.head()
# Out:
#    rank                    Youtuber  subscribers     video views  \
# 0     1                    T-Series    245000000  22800000000000
# 1     2              YouTube Movies    170000000               0
# 2     3                     MrBeast    166000000     28368841870
# 3     4  Cocomelon - Nursery Rhymes    162000000  16400000000000
# 4     5                   SET India    159000000  14800000000000
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %% [markdown]
# ### 3.Entendendo os dados

# %%
df.shape
# Out:
# (995, 28)

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  7.481743e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.054114e+12   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+13  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    int64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %% [markdown]
# A.Analisando dados nulos

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %% [markdown]
# B. Analisando a frequencia de aparição

# %%
df['category'].value_counts()
# Out:
# Entertainment            241
# Music                    202
# People & Blogs           132
# Gaming                    94
# Comedy                    69
# Film & Animation          46
# Education                 45
# Howto & Style             40
# News & Politics           26
# Science & Technology      17
# Shows                     13
# Sports                    11
# Pets & Animals             4
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: category, dtype: int64

# %% [markdown]
# C. Retirando dados nulos

# %%
df = df.dropna(subset=['category'])

# %%
df.shape
# Out:
# (949, 28)

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                     0
# Title                                        0
# uploads                                      0
# Country                                    115
# Abbreviation                               115
# channel_type                                27
# video_views_rank                             1
# country_rank                               109
# channel_type_rank                           29
# video_views_for_the_last_30_days            50
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               326
# created_year                                 5
# ...

# %%
df = df.dropna(subset='Country')

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                     0
# Title                                        0
# uploads                                      0
# Country                                      0
# Abbreviation                                 0
# channel_type                                 7
# video_views_rank                             1
# country_rank                                 1
# channel_type_rank                            9
# video_views_for_the_last_30_days            22
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               271
# created_year                                 3
# ...

# %%
df['channel_type'].value_counts()
# Out:
# Entertainment    273
# Music            195
# Games             82
# People            59
# Comedy            48
# Education         44
# Film              34
# Howto             31
# News              29
# Tech              14
# Sports            11
# Animals            3
# Nonprofit          2
# Autos              2
# Name: channel_type, dtype: int64

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers     video views  \
# 0     1                    T-Series    245000000  22800000000000
# 1     2              YouTube Movies    170000000               0
# 2     3                     MrBeast    166000000     28368841870
# 3     4  Cocomelon - Nursery Rhymes    162000000  16400000000000
# 4     5                   SET India    159000000  14800000000000
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %% [markdown]
# D. Substituindo os valores nulos por 0 (nos casos númericos)

# %%
df['subscribers_for_last_30_days'] = df['subscribers_for_last_30_days'].fillna(0)

# %%
df['subscribers_for_last_30_days'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# rank                                        0
# Youtuber                                    0
# subscribers                                 0
# video views                                 0
# category                                    0
# Title                                       0
# uploads                                     0
# Country                                     0
# Abbreviation                                0
# channel_type                                7
# video_views_rank                            1
# country_rank                                1
# channel_type_rank                           9
# video_views_for_the_last_30_days           22
# lowest_monthly_earnings                     0
# highest_monthly_earnings                    0
# lowest_yearly_earnings                      0
# highest_yearly_earnings                     0
# subscribers_for_last_30_days                0
# created_year                                3
# ...

# %% [markdown]
# E. Substituindo os valores nulo da categoria tipo de canal por "Entretenimento", a maior aparição dentro da base

# %%
df['channel_type'] = df['channel_type'].fillna('Entertainment')

# %%
df.isnull().sum()
# Out:
# rank                                        0
# Youtuber                                    0
# subscribers                                 0
# video views                                 0
# category                                    0
# Title                                       0
# uploads                                     0
# Country                                     0
# Abbreviation                                0
# channel_type                                0
# video_views_rank                            1
# country_rank                                1
# channel_type_rank                           9
# video_views_for_the_last_30_days           22
# lowest_monthly_earnings                     0
# highest_monthly_earnings                    0
# lowest_yearly_earnings                      0
# highest_yearly_earnings                     0
# subscribers_for_last_30_days                0
# created_year                                3
# ...

# %%
df['video_views_for_the_last_30_days'] = df['video_views_for_the_last_30_days'].fillna(0)

# %%
df.isnull().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           1
# country_rank                               1
# channel_type_rank                          9
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               3
# created_month                              3
# ...

# %% [markdown]
# F. Retirando valores nulos restantes

# %%
df = df.dropna(subset = ['channel_type_rank'])

# %%
df.isnull().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               1
# created_month                              1
# ...

# %%
df = df.dropna(subset = ['created_year'])

# %%
df.isnull().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               0
# created_month                              0
# ...

# %%
df = df.dropna(subset = ['Population'])

# %%
df.isnull().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               0
# created_month                              0
# ...

# %%
df.head(5
       )
# Out:
#    rank                    Youtuber  subscribers     video views  \
# 0     1                    T-Series    245000000  22800000000000
# 1     2              YouTube Movies    170000000               0
# 2     3                     MrBeast    166000000     28368841870
# 3     4  Cocomelon - Nursery Rhymes    162000000  16400000000000
# 4     5                   SET India    159000000  14800000000000
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df['created_year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 823 entries, 0 to 994
# Series name: created_year
# Non-Null Count  Dtype
# --------------  -----
# 823 non-null    float64
# dtypes: float64(1)
# memory usage: 12.9 KB

# %% [markdown]
# G. Alterando o tipo de dados de float para int, retirando as virgulas desnecessárias

# %%
df['created_year']= df['created_year'].astype(int)

# %%
df['created_date'] = df['created_date'].astype(int)

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers     video views  \
# 0     1                    T-Series    245000000  22800000000000
# 1     2              YouTube Movies    170000000               0
# 2     3                     MrBeast    166000000     28368841870
# 3     4  Cocomelon - Nursery Rhymes    162000000  16400000000000
# 4     5                   SET India    159000000  14800000000000
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df['Urban_population'] = df['Urban_population'].astype(int)

# %%
df.head(5)
# Out:
#    rank                    Youtuber  subscribers     video views  \
# 0     1                    T-Series    245000000  22800000000000
# 1     2              YouTube Movies    170000000               0
# 2     3                     MrBeast    166000000     28368841870
# 3     4  Cocomelon - Nursery Rhymes    162000000  16400000000000
# 4     5                   SET India    159000000  14800000000000
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df['subscribers_for_last_30_days'] = df['subscribers_for_last_30_days'].astype(int)

# %%
df.head(5)
# Out:
#    rank                    Youtuber  subscribers     video views  \
# 0     1                    T-Series    245000000  22800000000000
# 1     2              YouTube Movies    170000000               0
# 2     3                     MrBeast    166000000     28368841870
# 3     4  Cocomelon - Nursery Rhymes    162000000  16400000000000
# 4     5                   SET India    159000000  14800000000000
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                       2000000
# ...

# %%
df.index = df.index +1

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers     video views  \
# 1     1                    T-Series    245000000  22800000000000
# 2     2              YouTube Movies    170000000               0
# 3     3                     MrBeast    166000000     28368841870
# 4     4  Cocomelon - Nursery Rhymes    162000000  16400000000000
# 5     5                   SET India    159000000  14800000000000
#
#            category                       Title  uploads        Country  \
# 1             Music                    T-Series    20082          India
# 2  Film & Animation               youtubemovies        1  United States
# 3     Entertainment                     MrBeast      741  United States
# 4         Education  Cocomelon - Nursery Rhymes      966  United States
# 5             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 1           IN          Music  ...                       2000000
# ...

# %%
df = df.drop(columns = ['rank'])

# %%
df.head(5)
# Out:
#                      Youtuber  subscribers     video views          category  \
# 1                    T-Series    245000000  22800000000000             Music
# 2              YouTube Movies    170000000               0  Film & Animation
# 3                     MrBeast    166000000     28368841870     Entertainment
# 4  Cocomelon - Nursery Rhymes    162000000  16400000000000         Education
# 5                   SET India    159000000  14800000000000             Shows
#
#                         Title  uploads        Country Abbreviation  \
# 1                    T-Series    20082          India           IN
# 2               youtubemovies        1  United States           US
# 3                     MrBeast      741  United States           US
# 4  Cocomelon - Nursery Rhymes      966  United States           US
# 5                   SET India   116536          India           IN
#
#     channel_type  video_views_rank  ...  subscribers_for_last_30_days  \
# ...

# %% [markdown]
# H. Exportando a base de dados em Excel

# %%
df.to_excel('Youtube_dataset.xlsx')
